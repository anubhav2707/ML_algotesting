# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("./BIOCON.csv", parse_dates=[0],index_col=0)

df
# Out:
#            Open Price   High Price   Low Price   Close Price       WAP   \
# Date
# 12-Oct-20      453.45       463.55      444.05        462.55    455.43
# 09-Oct-20      474.40       477.90      449.40        451.30    463.55
# 08-Oct-20      454.30       473.70      451.45        469.35    461.05
# 07-Oct-20      461.70       463.10      448.60        452.10    454.57
# 06-Oct-20      461.00       469.00      454.95        457.65    461.36
# ...                ...          ...         ...           ...       ...
# 06-Jan-05      501.00       504.50      493.00        494.85    498.21
# 05-Jan-05      511.00       521.00      492.00        498.85    507.18
# 04-Jan-05      516.90       516.90      508.20        510.10    512.23
# 03-Jan-05      512.00       517.00      510.00        513.85    513.52
# Average        428.52       435.19      421.35        427.45    428.45
#
#            No.of Shares   No. of Trades   Total Turnover (Rs.)   \
# Date
# ...

# %%
df.columns
# Out:
# Index([' Open Price ', ' High Price ', ' Low Price ', ' Close Price ', ' WAP ',
#        ' No.of Shares ', ' No. of Trades ', ' Total Turnover (Rs.) ',
#        ' Deliverable Quantity ', ' % Deli. Qty to Traded Qty ',
#        ' Spread High-Low ', ' Spread Close-Open '],
#       dtype='object')

# %%
df['Spread High-Open']=df['High Price']-df['Open Price']
df['Spread Open-Low']=df['Open Price']-df['Low Price']
df['Open-prev_Close']=0
for i in range(len(df)):
    df.iloc[i,df.columns.get_loc("Open-prev_Close")]=df.iloc[i][0]-df.iloc[i-1][3]
    

df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'High Price'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-63e81d467023> in <module>
# ...

# %%
high_low=[]
open_prev_close=[]
high_open=[]
open_low=[]
l=[25,50,100,150,0,-0.05,-25,-50]

def abc(col,name):
    for pos in range(8):
        v=0
        for i in range(len(df)):
            if l[pos]>=0:
                if df.iloc[i][col]>l[pos]:
                    v=v+1
            else:
                if df.iloc[i][col]<l[pos]:
                    v=v+1
        name.append([l[pos],int(v/len(df)*100)])
abc(10,high_low)
abc(14,open_prev_close)
abc(12,high_open)
abc(13,open_low)

# %%
high_low

# %%
open_prev_close

# %%
high_open

# %%
open_low
